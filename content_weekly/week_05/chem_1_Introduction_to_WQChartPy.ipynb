# %% [markdown]
# # Introduction to Hydrogeochemical Data Visualization with WQChartPy
#
# ## Learning Objectives
# By the end of this notebook, you will be able to:
# 1. Understand the basics of hydrogeochemical data visualization
# 2. Install and import WQChartPy
# 3. Load and prepare water chemistry data for plotting
# 4. Create basic hydrogeochemical diagrams
# 5. Interpret common hydrogeochemical plots
#
# ## What is WQChartPy?
#
# WQChartPy is a Python package for creating geochemical diagrams used in water quality analysis and hydrogeochemistry. It can generate 12 different types of diagrams including:
#
# - **Piper diagrams** (Triangle, Rectangle, Color-coded, Contour-filled)
# - **Stiff diagrams**
# - **Durov diagrams**
# - **Schoeller diagrams**
# - **Gibbs diagrams**
# - **Chadha diagrams**
# - **Gaillardet diagrams**
# - **HFE-D diagrams**
# - **Chernoff faces**

# %% [markdown]
# ## Installation and Setup

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Understanding Water Chemistry Data Format
#
# WQChartPy requires data in a specific format. Let's examine the required columns:

# %%
from wqchartpy import triangle_piper

# Load the template dataset
df = pd.read_csv('./datasets/template_dataset.csv')

# Display the data
print("\nData shape:", df.shape)
df
# Out:
# Data shape: (6, 16)
#     Sample      Label  Color Marker  Size  Alpha   pH   Ca  Mg  Na    K  HCO3  \
# 0  sample1  Cluster_A    red      o    30    0.6  7.8   32   6  28  2.8    73
# 1  sample2  Cluster_B  green      s    30    0.6  7.6   46  11  17  0.7   201
# 2  sample3  Cluster_B  green      s    30    0.6  7.5   54  11  16  2.4   207
# 3  sample4  Cluster_C   blue      ^    30    0.6  7.7   50  11  25  2.8   244
# 4  sample5  Cluster_C   blue      ^    30    0.6  7.4   50  22  25  0.5   305
# 5  sample6  Cluster_A    red      o    30    0.6  7.1  134  21  39  6.4   275
#
#    CO3  Cl  SO4  TDS
# 0    0  43   48  233
# 1    0  14    9  299
# 2    0  18   10  377
# 3    0  18    9  360
# 4    0  11    9  424
# 5    0  96  100  673

# %% [markdown]
# ### Required Columns Explained:
#
# 1. **Sample**: Sample name or ID
# 2. **Label**: Group identifier (used for categorizing samples)
# 3. **Color**: Color for plotting (matplotlib color names or hex codes)
# 4. **Marker**: Marker style for plotting (matplotlib marker codes)
# 5. **Size**: Marker size for plotting
# 6. **Alpha**: Transparency (0 = transparent, 1 = opaque)
# 7. **pH**: pH value
# 8. **Major Ions**: Ca, Mg, Na, K, HCO3, CO3, Cl, SO4 (all in mg/L)
# 9. **TDS**: Total Dissolved Solids (mg/L)

# %%
# Basic statistics for the template data
print("Basic Statistics for Template Dataset:")
print("======================================")

# Select only the chemical parameter columns
chem_cols = ['pH', 'Ca', 'Mg', 'Na', 'K', 'HCO3', 'CO3', 'Cl', 'SO4', 'TDS']
df[chem_cols].describe().round(2)
# Out:
# Basic Statistics for Template Dataset:
# ======================================
#          pH      Ca     Mg     Na     K    HCO3  CO3     Cl     SO4     TDS
# count  6.00    6.00   6.00   6.00  6.00    6.00  6.0   6.00    6.00    6.00
# mean   7.52   61.00  13.67  25.00  2.60  217.50  0.0  33.33   30.83  394.33
# std    0.25   36.57   6.38   8.37  2.13   81.15  0.0  32.75   37.26  151.74
# min    7.10   32.00   6.00  16.00  0.50   73.00  0.0  11.00    9.00  233.00
# 25%    7.43   47.00  11.00  19.00  1.12  202.50  0.0  15.00    9.00  314.25
# 50%    7.55   50.00  11.00  25.00  2.60  225.50  0.0  18.00    9.50  368.50
# 75%    7.68   53.00  18.50  27.25  2.80  267.25  0.0  36.75   38.50  412.25
# max    7.80  134.00  22.00  39.00  6.40  305.00  0.0  96.00  100.00  673.00

# %%
print("\nSample Groups:")
df['Label'].value_counts()
# Out:
# Sample Groups:
# Label
# Cluster_A    2
# Cluster_B    2
# Cluster_C    2
# Name: count, dtype: int64

# %%
print("\nTDS Range by Group:")
for group in df['Label'].unique():
    group_data = df[df['Label'] == group]
    print(f"{group}: {group_data['TDS'].min():.1f} - {group_data['TDS'].max():.1f} mg/L")
# Out:
# TDS Range by Group:
# Cluster_A: 233.0 - 673.0 mg/L
# Cluster_B: 299.0 - 377.0 mg/L
# Cluster_C: 360.0 - 424.0 mg/L

# %% [markdown]
# ## Your First Hydrogeochemical Plot: Piper Diagram
#
# The Piper diagram is one of the most widely used plots in hydrogeochemistry. It shows the relative concentrations of major cations and anions.

# %%
# Import the triangle Piper module
from wqchartpy import triangle_piper

triangle_piper.plot(
    df, unit='mg/L', 
    figname='./plots/example_triangle_piper', figformat='png'
)
# Out:
# Trilinear Piper plot created. Saving it to /Users/nkalauni/Documents/classes/3rd-sem/564 Tools/hwrs564a_course_materials_nkalauni/content_weekly/week_05

# %% [markdown]
# ## Understanding the Piper Diagram
#
# The Piper diagram consists of:
# - **Left triangle**: Cations (Ca²⁺, Mg²⁺, Na⁺+K⁺)
# - **Right triangle**: Anions (Cl⁻, SO₄²⁻, HCO₃⁻+CO₃²⁻)
# - **Central diamond**: Combined cation and anion composition
#
# ### Interpretation:
# - Points closer to corners indicate dominance of that ion
# - Points in the center indicate mixed water types
# - Clustering indicates similar water chemistry

# %% [markdown]
# ## Creating Multiple Plot Types
#
# Let's create several different plot types to compare their strengths:

# %%
# Stiff diagram - creates unique 'fingerprints' for each water sample
from wqchartpy import stiff

stiff.plot(
    df,  unit='mg/L', 
    figname='./plots/stiff_diagram_example', figformat='png'
)
# Out:
# Stiff plot created for sample1. Saving it to /Users/nkalauni/Documents/classes/3rd-sem/564 Tools/hwrs564a_course_materials_nkalauni/content_weekly/week_05
#
# Stiff plot created for sample2. Saving it to /Users/nkalauni/Documents/classes/3rd-sem/564 Tools/hwrs564a_course_materials_nkalauni/content_weekly/week_05
#
# Stiff plot created for sample3. Saving it to /Users/nkalauni/Documents/classes/3rd-sem/564 Tools/hwrs564a_course_materials_nkalauni/content_weekly/week_05
#
# Stiff plot created for sample4. Saving it to /Users/nkalauni/Documents/classes/3rd-sem/564 Tools/hwrs564a_course_materials_nkalauni/content_weekly/week_05
#
# Stiff plot created for sample5. Saving it to /Users/nkalauni/Documents/classes/3rd-sem/564 Tools/hwrs564a_course_materials_nkalauni/content_weekly/week_05
#
# Stiff plot created for sample6. Saving it to /Users/nkalauni/Documents/classes/3rd-sem/564 Tools/hwrs564a_course_materials_nkalauni/content_weekly/week_05

# %%
# Gibbs diagram - helps identify water-rock interaction processes
from wqchartpy import gibbs

gibbs.plot(
    df, unit='mg/L', 
    figname='./plots/gibbs_example', figformat='png'
)
# Out:
# Gibbs plot created. Saving it to /Users/nkalauni/Documents/classes/3rd-sem/564 Tools/hwrs564a_course_materials_nkalauni/content_weekly/week_05

# %%
# Schoeller diagram - shows ion concentrations on a log scale
# Note: https://github.com/jyangfsu/WQChartPy/blob/main/wqchartpy/schoeller.py#L56-L76
from wqchartpy import schoeller

schoeller.plot(
    df, unit='mg/L', 
    figname='./plots/schoeller', figformat='png'
)
# Out:
# Schoeller diagram created. Saving it to /Users/nkalauni/Documents/classes/3rd-sem/564 Tools/hwrs564a_course_materials_nkalauni/content_weekly/week_05

# %% [markdown]
# ## Data Summary and Statistics

# %% [markdown]
# ## Exercise: Create Your Own Plot
#
# Try modifying the data and creating a new plot:

# %%
# Exercise: Modify colors and create a new Piper diagram
df_modified = df.copy()

# Change colors for each cluster - how to do this??
# TODO Need to do something here!

# Create the plot with modified colors
triangle_piper.plot(df_modified, 
                   unit='mg/L', 
                   figname='./plots/modified_piper', 
                   figformat='png')

print("Modified Piper diagram created with new colors!")
# Out:
# Trilinear Piper plot created. Saving it to /Users/nkalauni/Documents/classes/3rd-sem/564 Tools/hwrs564a_course_materials_nkalauni/content_weekly/week_05
#
# Modified Piper diagram created with new colors!

# %% [markdown]
# ## Key Takeaways
#
# 1. **Data Format**: WQChartPy requires specific column names and format
# 2. **Multiple Plot Types**: Different plots reveal different aspects of water chemistry
# 3. **Customization**: Colors, markers, and sizes can be customized for better visualization
# 4. **Interpretation**: Each plot type has specific interpretation guidelines

# %%
"""
Piper Diagram for Three Wells
- Upgradient Well: Fresh recharge water (blue)
- Downgradient Well: Evolved groundwater (green)
- Well near Gila River: Brackish river-influenced water (orange)
"""

import pandas as pd
import numpy as np
from wqchartpy import triangle_piper
import matplotlib.pyplot as plt

# Create the dataset in WQChartPy format
data = {
    'Sample': ['Upgradient Well (#1)', 'Downgradient Well (#2)', 'Well near Gila River (#3)'],
    'Label': ['Upgradient', 'Downgradient', 'Gila River'],
    'Color': ['blue', 'green', 'orange'],  # Blue, Green, Orange-Red
    'Marker': ['o', 's', '^'],  # Circle, Square, Triangle
    'Size': [100, 100, 100],
    'Alpha': [0.7, 0.7, 0.7],
    'pH': [7.2, 7.9, 7.7],
    'Ca': [40, 40, 650],
    'Mg': [8.1, 18, 97],
    'Na': [37, 140, 670],
    'K': [1.9, 2.7, 11],
    'HCO3': [200, 370, 190],
    'CO3': [0, 0, 0],  # Assumed 0 as not reported
    'Cl': [13, 37, 1400],
    'SO4': [11, 72, 1800],
    'TDS': [31.8, 18.6, 21.4]  # Temperature values from your table
}

# Create DataFrame
df = pd.DataFrame(data)

# Display the formatted data
print("Formatted Data for WQChartPy:")
print("="*80)
print(df.to_string(index=False))
print("\n")

# Create the Piper diagram
print("Generating Piper diagram...")
triangle_piper.plot(
    df, 
    unit='mg/L', 
    figname='./three_wells_piper', 
    figformat='png'
)

print("\nPiper diagram created successfully!")
print("\nInterpretation Guide:")
print("-" * 80)
print("• Upgradient Well (Blue ●): Fresh recharge water")
print("• Downgradient Well (Green ■): Water evolved through aquifer interaction")
print("• Gila River Well (Orange ▲): Brackish, river-influenced water")
print("\nLook for:")
print("- Evolution patterns from upgradient to downgradient")
print("- Distinct brackish signature of the Gila River well")
print("- Changes in dominant ion composition")
# Out:
# Formatted Data for WQChartPy:
# ================================================================================
#                    Sample        Label  Color Marker  Size  Alpha  pH  Ca   Mg  Na    K  HCO3  CO3   Cl  SO4  TDS
#      Upgradient Well (#1)   Upgradient   blue      o   100    0.7 7.2  40  8.1  37  1.9   200    0   13   11 31.8
#    Downgradient Well (#2) Downgradient  green      s   100    0.7 7.9  40 18.0 140  2.7   370    0   37   72 18.6
# Well near Gila River (#3)   Gila River orange      ^   100    0.7 7.7 650 97.0 670 11.0   190    0 1400 1800 21.4
#
#
# Generating Piper diagram...
# Trilinear Piper plot created. Saving it to /Users/nkalauni/Documents/classes/3rd-sem/564 Tools/hwrs564a_course_materials_nkalauni/content_weekly/week_05
#
#
# Piper diagram created successfully!
#
# Interpretation Guide:
# --------------------------------------------------------------------------------
# • Upgradient Well (Blue ●): Fresh recharge water
# • Downgradient Well (Green ■): Water evolved through aquifer interaction
# • Gila River Well (Orange ▲): Brackish, river-influenced water
#
# Look for:
# - Evolution patterns from upgradient to downgradient
# - Distinct brackish signature of the Gila River well
# - Changes in dominant ion composition
